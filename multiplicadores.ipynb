# %%
for i in range(7,13):
    print(f"Tabla del {i}")
    for j in range(1, 16):
        print(f"{i}x{j }= " + str(i*j))
# Out:
# Tabla del 7
# 7x1= 7
# 7x2= 14
# 7x3= 21
# 7x4= 28
# 7x5= 35
# 7x6= 42
# 7x7= 49
# 7x8= 56
# 7x9= 63
# 7x10= 70
# 7x11= 77
# 7x12= 84
# 7x13= 91
# 7x14= 98
# 7x15= 105
# Tabla del 8
# 8x1= 8
# 8x2= 16
# 8x3= 24
# 8x4= 32
# 8x5= 40
# 8x6= 48
# 8x7= 56
# 8x8= 64
# 8x9= 72
# 8x10= 80
# 8x11= 88
# 8x12= 96
# 8x13= 104
# 8x14= 112
# 8x15= 120
# Tabla del 9
# 9x1= 9
# 9x2= 18
# 9x3= 27
# 9x4= 36
# 9x5= 45
# 9x6= 54
# 9x7= 63
# 9x8= 72
# 9x9= 81
# 9x10= 90
# 9x11= 99
# 9x12= 108
# 9x13= 117
# 9x14= 126
# 9x15= 135
# Tabla del 10
# 10x1= 10
# 10x2= 20
# 10x3= 30
# 10x4= 40
# 10x5= 50
# 10x6= 60
# 10x7= 70
# 10x8= 80
# 10x9= 90
# 10x10= 100
# 10x11= 110
# 10x12= 120
# 10x13= 130
# 10x14= 140
# 10x15= 150
# Tabla del 11
# 11x1= 11
# 11x2= 22
# 11x3= 33
# 11x4= 44
# 11x5= 55
# 11x6= 66
# 11x7= 77
# 11x8= 88
# 11x9= 99
# 11x10= 110
# 11x11= 121
# 11x12= 132
# 11x13= 143
# 11x14= 154
# 11x15= 165
# Tabla del 12
# 12x1= 12
# 12x2= 24
# 12x3= 36
# 12x4= 48
# 12x5= 60
# 12x6= 72
# 12x7= 84
# ...
